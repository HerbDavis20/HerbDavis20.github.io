# %% [markdown]
# # Introduction to Portfolio Optimization with Python

# %% [markdown]
# $\textbf{by Ahmed Pirzada, University of Bristol}$
#
# $\textbf{aj.pirzada@bristol.ac.uk}$
#
# $\textbf{26th November 2025}$

# %% [markdown]
# # Learning Objectives
#
# - Understand the inputs to a portfolio problem: assets, period, prices, and returns.
# - Compute daily and annualised returns and the covariance matrix.
# - Formulate and solve mean–variance optimisation with constraints (weights sum to 1, no shorting).
# - Interpret optimal weights, risk (variance), and expected return; plot results.
# - Find the tangency portfolio by maximising the Sharpe ratio and compare allocations.

# %% [markdown]
# ## Step 1: Import libraries we need

# %% [markdown]
# - Install and Import `yfinance` library to download stock price data from Yahoo Finance

# %%
# Install yfinance to download stock price data from Yahoo Finance.
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.2.50)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\herbd\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas>=1.3.0 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\herbd\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
# Import yfinance library to the environment
import yfinance as yf

# %% [markdown]
# - Import `numpy` library to handle numerical operations

# %%
import numpy as np  # To handle numerical operations

# %% [markdown]
# - Import `minimize` function from `scipy` library for optimisation

# %%
from scipy.optimize import minimize  # For solving optimization problems

# %% [markdown]
# - Import `matplotlib.pyplot` for visualisation

# %%
import matplotlib.pyplot as plt  # For plotting charts
import plotly.express as px  # For interactive visualizations

# %% [markdown]
# ## Step 2: Specify which stocks we want to analyse and define the time period

# %% [markdown]
# - Choose tickers and the sample window; this controls which data are downloaded and analysed.

# %%
tickers = ['NVDA', 'GOOGL', 'TSLA', 'MSFT']   # List of stocks
start_date = '2015-01-01'
end_date = '2025-10-01'

# %% [markdown]
# ## Step 3: Download adjusted close prices.

# %% [markdown]
# - Download adjusted close price data from Yahoo Finance

# %%
# Get Data: yf.download(List, start= , end= , auto_adjust=True)['Close']
data = yf.download(tickers, start=start_date, end=end_date, auto_adjust=True)['Close']
# Out:
# Failed to get ticker 'MSFT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GOOGL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NVDA' reason: Expecting value: line 1 column 1 (char 0)
# [                       0%                       ]Failed to get ticker 'TSLA' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  4 of 4 completed
#
# 4 Failed downloads:
# ['MSFT', 'GOOGL', 'NVDA', 'TSLA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')

# %% [markdown]
# - Use `head()` method to preview your data

# %%
# # Display the first few rows of the data
data.head()
# Out:
# Empty DataFrame
# Columns: [GOOGL, MSFT, NVDA, TSLA]
# Index: []

# %% [markdown]
# ## Step 4: Visualize prices for these stocks

# %% [markdown]
# - Use `plotly` library to visually inspect data using `px.line()`

# %%
# Plotly line chart: px.line(Data, title= , labels={ , })
fig = px.line(data,
              title='stock prices',
              labels={"index": "Date", "value": "Price"}
)

fig.update_layout(template='plotly_white',
                  title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f799f4bf-2d99-4818-985b-547e9edf8587" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f799f4bf-2d99-4818-985b-547e9edf8587")) {                    Plotly.newPlot(                        "f799f4bf-2d99-4818-985b-547e9edf8587",                        [{"hovertemplate":"Ticker=GOOGL\u003cbr\u003eDate=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOOGL","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"GOOGL","showlegend":true,"x":["2015-01-02T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-15T00:00:00","2015-06-16T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-19T00:00:00","2015-06-22T00:00:00","2015-06-23T00:00:00","2015-06-24T00:00:00","2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00","2015-07-01T00:00:00","2015-07-02T00:00:00","2015-07-06T00:00:00","2015-07-07T00:00:00","2015-07-08T00:00:00","2015-07-09T00:00:00","2015-07-10T00:00:00","2015-07-13T00:00:00","2015-07-14T00:00:00","2015-07-15T00:00:00","2015-07-16T00:00:00","2015-07-17T00:00:00","2015-07-20T00:00:00","2015-07-21T00:00:00","2015-07-22T00:00:00","2015-07-23T00:00:00","2015-07-24T00:00:00","2015-07-27T00:00:00","2015-07-28T00:00:00","2015-07-29T00:00:00","20 ...

# %% [markdown]
# ## Step 5: Calculate daily returns from prices

# %% [markdown]
# - Use `pct_change()` method from `numpy` library to compute daily percentage returns for each of your stock.
# - Use `dropna()` method to drop missing observations.

# %%
# Daily returns calculation
returns = data.pct_change().dropna()  # Drop the first row which will be NaN

# %% [markdown]
# ## Step 6: Estimate expected annual returns and covariance matrix for returns

# %% [markdown]
# - Use `mean()` method to calculate average (expected) stock returns and annualise these.

# %%
# Multiplying daily values by 252 converts them approximately to annual values, assuming 252 trading days per year
expected_returns = returns.mean() * 252

# %% [markdown]
# - Use `cov()` method to calculate variance-covariance matrix for stock returns.

# %%
# Calculate the covariance matrix of returns
cov_matrix = returns.cov() * 252

# %% [markdown]
# - Print expected returns and the covariance matrix

# %%
# Print expected returns and covariance matrix

print(f"\nExpected annual returns:")
print(expected_returns)

print("\nCovariance matrix:")
print(cov_matrix)
# Out:
# Expected annual returns:
# Ticker
# GOOGL    0.248981
# MSFT     0.275725
# NVDA     0.674961
# TSLA     0.486111
# dtype: float64
#
# Covariance matrix:
# Ticker     GOOGL      MSFT      NVDA      TSLA
# Ticker
# GOOGL   0.083032  0.054248  0.074193  0.063690
# MSFT    0.054248  0.073162  0.080152  0.063731
# NVDA    0.074193  0.080152  0.239567  0.117014
# TSLA    0.063690  0.063731  0.117014  0.336222

# %% [markdown]
# ## Step 7: VISUALISE data for Expected Returns and Covaraince Matrix

# %% [markdown]
# - $\textbf{Expected Returns}$: Use `plotly` library to plot the bar chart using `px.bar()`

# %%
# Ploty bar chart: fig = px.bar(Data, x= , y= , color= , title= , labels= )
fig = px.bar(
    expected_returns,
    x=expected_returns.index,
    y=expected_returns.values,
    color=expected_returns.index,
    title="Expected Returns",
    labels={"x": "Asset", "y": "Expected Return"}
)

fig.update_layout(
    template="plotly_white",
    title_x=0.5,             # centre title
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ff7b545-2dd5-40fd-9abd-ff309cb06c7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ff7b545-2dd5-40fd-9abd-ff309cb06c7b")) {                    Plotly.newPlot(                        "6ff7b545-2dd5-40fd-9abd-ff309cb06c7b",                        [{"alignmentgroup":"True","hovertemplate":"Ticker=%{x}\u003cbr\u003eExpected Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOOGL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"GOOGL","offsetgroup":"GOOGL","orientation":"v","showlegend":true,"textposition":"auto","x":["GOOGL"],"xaxis":"x","y":[0.24898099283212577],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ticker=%{x}\u003cbr\u003eExpected Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MSFT","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"MSFT","offsetgroup":"MSFT","orientation":"v","showlegend":true,"textposition":"auto","x":["MSFT"],"xaxis":"x","y":[0.27572512115404907],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ticker=%{x}\u003cbr\u003eExpected Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NVDA","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"NVDA","offsetgroup":"NVDA","orientation":"v","showlegend":true,"textposition":"auto","x":["NVDA"],"xaxis":"x","y":[0.6749605969740434],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ticker=%{x}\u003cbr\u003eExpected Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TSLA","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"TSLA","offsetgroup":"TSLA","orientation":"v","showlegend":true,"textposition":"auto","x":["TSLA"],"xaxis":"x","y":[0.4861111629979269],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram ...

# %% [markdown]
# - $\textbf{Covariance Matrix}$: Use `plotly` library to plot the heatmap using `px.imshow()`

# %%
# Ploty heatmap: fig = px.imshow(Data, title= , labels= , text_auto=True , color_continuous_scale="Reds" , aspect="auto" )
fig = px.imshow(
    cov_matrix,
    title="Covariance Matrix Heatmap",
    labels=dict(x="", y=""),
    text_auto=True,          # shows numbers in each cell
    color_continuous_scale="Reds",  # Shades of red color
    aspect="auto"
)


fig.update_layout(
    template="plotly_white",
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f7c76aa7-57f2-42ad-bf10-97a9499f7b66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7c76aa7-57f2-42ad-bf10-97a9499f7b66")) {                    Plotly.newPlot(                        "f7c76aa7-57f2-42ad-bf10-97a9499f7b66",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["GOOGL","MSFT","NVDA","TSLA"],"y":["GOOGL","MSFT","NVDA","TSLA"],"z":[[0.08303248650982795,0.05424786894168932,0.07419340142080123,0.0636898557419683],[0.05424786894168932,0.07316157360252964,0.08015185053122817,0.06373145210851072],[0.07419340142080123,0.08015185053122817,0.2395670845527843,0.11701449382655395],[0.0636898557419683,0.06373145210851072,0.11701449382655395,0.3362215979720281]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar ...

# %% [markdown]
# ## Step 7: Setup the Optimisation Problem i.e. Objective and Constraints

# %% [markdown]
# - Define the objective (Sharpe Ratio), constraints (weights sum=1, bounds) and the initial guess

# %%
# Define Objective Function: Maximising the Shape Ratio is the same as Minimising the -ve of the Sharpe Ratio
def neg_sharpe_ratio(weights, expected_returns, cov_matrix):

    portfolio_return = np.dot(weights, expected_returns)

    portfolio_risk = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))

    return - portfolio_return / portfolio_risk

# Constraints: weights sum to 1
constraints = ({'type': 'eq', 'fun': lambda w: np.sum(w) - 1})

# No short selling: weights between 0 and 1
bounds = tuple((0,1) for _ in tickers)

# Initial guess: equal distribution
init_guess = np.array(len(tickers) * [1. / len(tickers)])

# %% [markdown]
# ## Step 8: Run the optimization using Sequential Least Squares Programming (SLSQP)

# %% [markdown]
# - Use the `minimize` function from `scipi` library to solve the optimisation problem

# %%
# Minimise function: miximize(Objective, Initial Guess, args=(Expected Returns, Covariance Matrix), method='SLSQP', bounds= , constraints= )
result = minimize(neg_sharpe_ratio, init_guess, args=(expected_returns, cov_matrix),
                  method='SLSQP', bounds=bounds, constraints=constraints)

result
# Out:
#      message: Optimization terminated successfully
#      success: True
#       status: 0
#          fun: -1.4209232281515798
#            x: [ 1.673e-02  2.150e-01  6.344e-01  1.339e-01]
#          nit: 7
#          jac: [ 1.527e-04 -6.112e-04  3.076e-04 -5.082e-04]
#         nfev: 36
#         njev: 7
#  multipliers: [ 1.234e-04]

# %% [markdown]
# ## Step 9: VISUALISE optimal allocation in a bar chart and Calculate portfolio risk, return, sharpe ratio

# %% [markdown]
# - Get information on optimal weights from the results

# %%
# Get weights which maximise the Sharpe Ratio
sharpe_weights = result.x

# %% [markdown]
# - Visualise Optimal Weights using Bar Chart

# %%
# Plotly bar chart: fig = px.bar(Data, x= , y= , color= , title= , labels= )
fig = px.bar(sharpe_weights,
            x=tickers,
            y=sharpe_weights,
            color=tickers,
            title="Optimal Portfolio Weights (Max Sharpe Ratio)",
            labels={"x": "Asset", "y": "Weight"})

fig.update_layout(
    template="plotly_white",
    title_x=0.5,             # centre title
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e035cdcf-1ec9-43da-bf74-4725e9be1fec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e035cdcf-1ec9-43da-bf74-4725e9be1fec")) {                    Plotly.newPlot(                        "e035cdcf-1ec9-43da-bf74-4725e9be1fec",                        [{"alignmentgroup":"True","hovertemplate":"color=NVDA\u003cbr\u003eAsset=%{x}\u003cbr\u003eWeight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NVDA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"NVDA","offsetgroup":"NVDA","orientation":"v","showlegend":true,"textposition":"auto","x":["NVDA"],"xaxis":"x","y":[0.016725375987233],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=GOOGL\u003cbr\u003eAsset=%{x}\u003cbr\u003eWeight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOOGL","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"GOOGL","offsetgroup":"GOOGL","orientation":"v","showlegend":true,"textposition":"auto","x":["GOOGL"],"xaxis":"x","y":[0.21497596784616085],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=TSLA\u003cbr\u003eAsset=%{x}\u003cbr\u003eWeight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TSLA","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"TSLA","offsetgroup":"TSLA","orientation":"v","showlegend":true,"textposition":"auto","x":["TSLA"],"xaxis":"x","y":[0.6343812239300578],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=MSFT\u003cbr\u003eAsset=%{x}\u003cbr\u003eWeight=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MSFT","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"MSFT","offsetgroup":"MSFT","orientation":"v","showlegend":true,"textposition":"auto","x":["MSFT"],"xaxis":"x","y":[0.13391743223654848],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888," ...

# %% [markdown]
# $\textbf{Calculate:}$
# - $\textbf{Portfolio return}$: $R^{*}$ = $\textbf{w}^{T}\mu$
# - $\textbf{Portfolio risk}$: $\sigma^{*}$ = $\sqrt{\textbf{w}^{T} \Omega \textbf{w}}$
# - $\textbf{Sharpe ratio}$: $S^{*}$ = $\frac{R^{*}}{\sigma^{*}}$

# %% [markdown]
# - Use `np.dot()` method to calculate portfolio return using sharpe_weights and expected_returns

# %%
# Portfolio return: R* = w^T * mu
sharpe_return = np.dot(sharpe_weights, expected_returns)

# %% [markdown]
# - Use `sqrt()` and `np.dot()` to calculate portfolio risk using sharpe_weights and expected_returns

# %%
# Portfolio risk: σ* = sqrt(w^T * Ω * w)
# Hint: you need two dot products i.e. np.dot( , np.dot( , ) )
sharpe_risk = np.sqrt(np.dot(sharpe_weights.T, np.dot(cov_matrix, sharpe_weights)))

# %% [markdown]
# - Use `f"..."` to print the results

# %%
print(f"\nOptimal Portfolio Expected Return: {sharpe_return:.2%}")
print(f"\nOptimal Portfolio Risk (Std Dev): {sharpe_risk:.2%}")
print(f"\nOptimal Portfolio Sharpe Ratio: {sharpe_return/sharpe_risk:.2f}")
# Out:
# Optimal Portfolio Expected Return: 55.67%
#
# Optimal Portfolio Risk (Std Dev): 39.18%
#
# Optimal Portfolio Sharpe Ratio: 1.42

# %% [markdown]
# ## Step 10: Plot the efficient frontier

# %% [markdown]
# - Generate many random portfolios to trace the efficient frontier of risk vs return.

# %%
# Generate a range of target returns to explore
num_portfolios = 10000
results = np.zeros((3, num_portfolios))
num_assets = len(tickers)

for i in range(num_portfolios):
    # Generate random weights that sum to 1
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    # Calculate portfolio return and risk
    port_return = np.dot(weights, expected_returns)
    port_risk = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    # Store results
    results[0,i] = port_risk
    results[1,i] = port_return
    results[2,i] = (port_return) / port_risk  # Sharpe ratio (risk-free rate not subtracted)


# Plotly scatter plot: px.scatter(x= , y= , c= , cmap= , marker= , s= , alpha= )
fig = px.scatter(
    x=results[0,:],
    y=results[1,:],
    color=results[2,:],
    color_continuous_scale='Viridis',
    title='Efficient Frontier',
    labels={'x': 'Risk (Std Dev)', 'y': 'Portfolio Return', 'color': 'Sharpe Ratio'}
)

fig.add_scatter(
    x=[sharpe_risk],
    y=[sharpe_return],
    mode='markers',
    marker=dict(size=14, color='red', symbol='star'),
    name='Optimal Portfolio'
)

fig.update_layout(template='plotly_white',
                  title_x=0.5,
                  legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

fig.show()

# %% [markdown]
# # Student Notes: Code Explanations
#
# This notebook builds an end-to-end portfolio optimiser. Use these notes to connect the code to the concepts.
#
# 1) Setup and data
# - Import libraries, pick tickers, and download adjusted close prices for the chosen period.
# - Plot prices to get a visual sense of behaviour before computing returns.
#
# 2) Returns and inputs
# - Compute daily returns and annualise mean and covariance (≈252 trading days).
# - These become the inputs to mean–variance optimisation.
#
# 3) Mean–variance optimisation
# - Objective: minimise portfolio variance subject to weights summing to 1 and bounds.
# - Solve with SLSQP and display the resulting allocation and statistics.
#
# 4) Efficient frontier
# - Simulate many random portfolios to trace risk–return trade-offs and visualise the frontier.
#
# 5) Tangency (Sharpe-maximising) portfolio
# - Reframe the objective to maximise Sharpe ratio and compute the tangency weights.
# - Compare allocations to the variance-minimising solution and overlay on the frontier.
#
# Tips
# - If variables are undefined, re-run cells from the top; many depend on earlier outputs.
# - Use `array.shape`, `df.head()`, and printed stats to sanity-check results.
# - Consider transaction costs and constraints (e.g., no shorting) when interpreting weights.
